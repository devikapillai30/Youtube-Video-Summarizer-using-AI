# %% [markdown]
# <a href="https://colab.research.google.com/github/devikapillai30/Youtube-Video-Summarizer-using-AI/blob/main/ai_yt_summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai==0.28
# !pip install yt-dlp
# Out:
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.10.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2024.8.30)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.14.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->openai==0.28) (4.12.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->openai==0.28) (0.2.0)
# Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: openai
# Successfully installed openai-0.28.0
# Collecting yt-dlp
#   Downloading yt_dlp-2024.10.7-py3-none-any.whl.metadata (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.3/171.3 kB 2.8 MB/s eta 0:00:00
# Collecting brotli (from yt-dlp)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2024.8.30)
# Collecting mutagen (from yt-dlp)
#   Downloading mutagen-1.47.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting pycryptodomex (from yt-dlp)
#   Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.2.3)
# Collecting websockets>=13.0 (from yt-dlp)
#   Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp) (3.10)
# Downloading yt_dlp-2024.10.7-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 38.0 MB/s eta 0:00:00
# Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 11.8 MB/s eta 0:00:00
# Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 53.8 MB/s eta 0:00:00
# Downloading mutagen-1.47.0-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 13.6 MB/s eta 0:00:00
# Downloading pycryptodomex-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 60.9 MB/s eta 0:00:00
# Installing collected packages: brotli, websockets, pycryptodomex, mutagen, yt-dlp
# Successfully installed brotli-1.1.0 mutagen-1.47.0 pycryptodomex-3.21.0 websockets-13.1 yt-dlp-2024.10.7

# %%
#importing libraries
import os
import os
import shutil
import librosa
import openai
import soundfile as sf
import yt_dlp
from yt_dlp.utils import DownloadError
os.environ["OPENAI_API_KEY"] = "my_api_key" #removed for safety
assert os.getenv("OPENAI_API_KEY") is not None, "Set your openAI API key"

# %%
def find_audio_files(path, extension=".mp3"):
    """Recursively find all files with the given extension in the specified path."""
    audio_files = []  # List to store matching audio files

    for root, dirs, files in os.walk(path):  # Traverse directory tree
        for f in files:  # Iterate over files in the current directory
            if f.endswith(extension):  # Check file extension
                audio_files.append(os.path.join(root, f))  # Add full path to list

    return audio_files  # Return the list of audio files

# %%
def youtube_to_mp3(youtube_url: str, output_dir: str) -> str:
    """Download the audio from a youtube video, save it to output_dir as an .mp3 file.

    Returns the filename of the savied video.
    """

    # Configuration for downloading audio
    ydl_config = {
        "format": "bestaudio/best",  # Best audio format
        "postprocessors": [{
            "key": "FFmpegExtractAudio",  # Extract audio using FFmpeg
            "preferredcodec": "mp3",  # Convert to MP3
            "preferredquality": "192",  # Set quality
        }],
        "outtmpl": os.path.join(output_dir, "%(title)s.%(ext)s"),  # Output filename template
        "verbose": True,  # Verbose output
    }

    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    print(f"Downloading video from {youtube_url}")

    # Attempt to download audio
    try:
        with yt_dlp.YoutubeDL(ydl_config) as ydl:
            ydl.download([youtube_url])
    except DownloadError:
        # Retry download on failure
        with yt_dlp.YoutubeDL(ydl_config) as ydl:
            ydl.download([youtube_url])

    # Return the name of the saved audio file
    audio_filename = find_audio_files(output_dir)[0]
    return audio_filename

# %%
def chunk_audio(filename, segment_length: int, output_dir):
    """segment length is in seconds
    Necessary for long audio files
    Whisper and ChatGPT have limits of how much text and audio can be processed"""

    print(f"Chunking audio to {segment_length} second segments...")

    if not os.path.isdir(output_dir):
        os.mkdir(output_dir)

    # load audio file
    audio, sr = librosa.load(filename, sr=44100)

    # calculate duration in seconds
    duration = librosa.get_duration(y=audio, sr=sr)

    # calculate number of segments
    num_segments = int(duration / segment_length) + 1

    print(f"Chunking {num_segments} chunks...")

    # iterate through segments and save them
    for i in range(num_segments):
        start = i * segment_length * sr
        end = (i + 1) * segment_length * sr
        segment = audio[start:end]
        sf.write(os.path.join(output_dir, f"segment_{i}.mp3"), segment, sr)

    chunked_audio_files = find_audio_files(output_dir)
    return sorted(chunked_audio_files)

# %%
def transcribe_audio(audio_files: list, output_file=None, model="whisper-1") -> list:

    print("converting audio to text...")

    transcripts = []
    for audio_file in audio_files:
        audio = open(audio_file, "rb")
        response = openai.Audio.transcribe(model, audio)
        transcripts.append(response["text"])

    if output_file is not None:
        # save all transcripts to a .txt file
        with open(output_file, "w") as file:
            for transcript in transcripts:
                file.write(transcript + "\n")

    return transcripts

# %%
def summarize(
    chunks: list[str], system_prompt: str, model="gpt-3.5-turbo", output_file=None
):
    """Summarize text chunks using OpenAI's GPT model."""

    print(f"Summarizing with {model=}")

    summaries = []  # List to store summaries
    for chunk in chunks:
        # Generate summary for each chunk
        response = openai.ChatCompletion.create(
            model=model,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": chunk},
            ],
        )
        summary = response["choices"][0]["message"]["content"]
        summaries.append(summary)  # Add summary to the list

    if output_file is not None:
        # Save summaries to a .txt file if specified
        with open(output_file, "w") as file:
            for summary in summaries:
                file.write(summary + "\n")

    return summaries  # Return the list of summaries

# %%
def summarize_youtube_video(youtube_url, outputs_dir):
    raw_audio_dir = f"{outputs_dir}/raw_audio/"
    chunks_dir = f"{outputs_dir}/chunks"
    transcripts_file = f"{outputs_dir}/transcripts.txt"
    summary_file = f"{outputs_dir}/summary.txt"
    segment_length = 10 * 60  # chunk to 10 minute segments

    if os.path.exists(outputs_dir):
        # delete the outputs_dir folder and start from scratch
        shutil.rmtree(outputs_dir)
        os.mkdir(outputs_dir)

    # download the video using youtube-dl
    audio_filename = youtube_to_mp3(youtube_url, output_dir=raw_audio_dir)

    # chunk each audio file to shorter audio files (not necessary for shorter videos...)
    chunked_audio_files = chunk_audio(
        audio_filename, segment_length=segment_length, output_dir=chunks_dir
    )

    # transcribe each chunked audio file using whisper speech2text
    transcriptions = transcribe_audio(chunked_audio_files, transcripts_file)

    # summarize each transcription using chatGPT
    system_prompt = """
    You are a helpful assistant that summarizes youtube videos.
    You are provided chunks of raw audio that were transcribed from the video's audio.
    Summarize the current chunk to succint and clear bullet points of its contents.
    """
    summaries = summarize(
        transcriptions, system_prompt=system_prompt, output_file=summary_file
    )

    system_prompt_tldr = """
    You are a helpful assistant that summarizes youtube videos.
    Someone has already summarized the video to key points.
    Summarize the key points to one or two sentences that capture the essence of the video.
    """
    # put the entire summary to a single entry
    long_summary = "\n".join(summaries)
    short_summary = summarize(
        [long_summary], system_prompt=system_prompt_tldr, output_file=summary_file
    )[0]

    return long_summary, short_summary

# %%
youtube_url = "https://www.youtube.com/watch?v=g1pb2aK2we4"
outputs_dir = "outputs/"

long_summary, short_summary = summarize_youtube_video(youtube_url, outputs_dir)

print("Summaries:")
print("=" * 80)
print("Long summary:")
print("=" * 80)
print(long_summary)
print()

print("=" * 80)
print("Video - TL;DR")
print("=" * 80)
print(short_summary)
# Out:
# [debug] Encodings: locale UTF-8, fs utf-8, out UTF-8, pref UTF-8
# [debug] youtube-dl version 2021.12.17
# [debug] Git HEAD: 6fece0a96
# [debug] Python version 3.10.10 (CPython) - macOS-12.5.1-arm64-arm-64bit
# [debug] exe versions: ffmpeg 5.1.2, ffprobe 5.1.2
# [debug] Proxy map: {}
# Downloading video from https://www.youtube.com/watch?v=g1pb2aK2we4
# [youtube] g1pb2aK2we4: Downloading webpage
# [debug] [youtube] Decrypted nsig W4nRgXSWiPJn52-Slf => OlowYsuH8lM-vw
# [debug] [youtube] Decrypted nsig YuEQ0PVn9gCpSD285g => cfnZo2wTpqs_NA
# [debug] Invoking downloader on 'https://rr2---sn-8qu-t0aee.googlevideo.com/videoplayback?expire=1680491064&ei=2O0pZOn5Jsri8wSj_LmQBA&ip=96.22.200.93&id=o-AKSCWvq_A7npJnpWy1jrHvsv3fbavwtghJ4h9NT-UvFB&itag=251&source=youtube&requiressl=yes&mh=JU&mm=31%2C29&mn=sn-8qu-t0aee%2Csn-t0a7sn7d&ms=au%2Crdu&mv=m&mvi=2&pl=18&initcwndbps=2166250&vprv=1&mime=audio%2Fwebm&ns=qZoaO-cj2tUp1b4NrTdWgyYM&gir=yes&clen=5840382&dur=302.621&lmt=1680218132527140&mt=1680469030&fvip=5&keepalive=yes&fexp=24007246&c=WEB&txp=5532434&n=OlowYsuH8lM-vw&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&sig=AOq0QJ8wRQIgctpRCn60WfhrbLwpLMNNQdjQgE3W1FirbksR8mF7wOkCIQD9fha-cCc4nMlqYu_N1AWKqBKcPMwmbBfIWZ8TDcJG1g%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRQIgESakLcUsvkN4DDbV4aOChgW9JaPUvhrY5_PtfMdxykYCIQDUyEbBxLpwjaDZkjfP5kj7t_w0XmoS8hlMjZSuJXiHzA%3D%3D'
# [dashsegments] Total fragments: 1
# [download] Destination: outputs//raw_audio/How stretching actually changes your muscles - Malachy McHugh.webm
# [download] 100.0% of ~5.57MiB at  8.57MiB/s ETA 00:007
# ERROR: giving up after 0 fragment retries
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/2v/40905qks05l4rnn4zz8r140w0000gp/T/ipykernel_21379/2672942998.py", line 4, in <module>
#     long_summary, short_summary = summarize_youtube_video(youtube_url, outputs_dir)
#   File "/var/folders/2v/40905qks05l4rnn4zz8r140w0000gp/T/ipykernel_21379/2296989415.py", line 14, in summarize_youtube_video
#     audio_filename = youtube_to_mp3(youtube_url, output_dir=raw_audio_dir)
#   File "/var/folders/2v/40905qks05l4rnn4zz8r140w0000gp/T/ipykernel_21379/628522897.py", line 28, in youtube_to_mp3
#     ydl.download([youtube_url])
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 2083, in download
#     res = self.extract_info(
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 812, in extract_info
#     return self.__extract_info(url, ie, download, extra_info, process)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 819, in wrapper
#     return func(self, *args, **kwargs)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 851, in __extract_info
#     return self.process_ie_result(ie_result, download, extra_info)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 885, in process_ie_result
#     return self.process_video_result(ie_result, download=download)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 1696, in process_video_result
#     self.process_info(new_info)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 1988, in process_info
#     success = dl(filename, info_dict)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 1927, in dl
#     return fd.download(name, info)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/downloader/common.py", line 376, in download
#     return self.real_download(filename, info_dict)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/downloader/dash.py", line 73, in real_download
#     self.report_error('giving up after %s fragment retries' % fragment_retries)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/downloader/common.py", line 175, in report_error
#     self.ydl.report_error(*args, **kargs)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 632, in report_error
#     self.trouble(error_message, tb)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 594, in trouble
#     tb_data = traceback.format_list(traceback.extract_stack())
#
# [debug] Encodings: locale UTF-8, fs utf-8, out UTF-8, pref UTF-8
# [debug] youtube-dl version 2021.12.17
# [debug] Git HEAD: 6fece0a96
# [debug] Python version 3.10.10 (CPython) - macOS-12.5.1-arm64-arm-64bit
# [debug] exe versions: ffmpeg 5.1.2, ffprobe 5.1.2
# [debug] Proxy map: {}
# [youtube] g1pb2aK2we4: Downloading webpage
# [debug] [youtube] Decrypted nsig zi5MGdaqq_kGzciHBN => 01jqWV79SJSwkQ
# [debug] [youtube] Decrypted nsig vRcfXB2BpYd4ZK2Zw1 => zrOSR_3_ZCnMCA
# [debug] Invoking downloader on 'https://rr2---sn-8qu-t0aee.googlevideo.com/videoplayback?expire=1680491066&ei=2u0pZMfqHuuwhwb45ZDIAQ&ip=96.22.200.93&id=o-AMoqrmgHbeD-qiNN1T0Qj0vk6TTRKKdtRGSZnExemlOp&itag=251&source=youtube&requiressl=yes&mh=JU&mm=31%2C29&mn=sn-8qu-t0aee%2Csn-t0a7ln7d&ms=au%2Crdu&mv=m&mvi=2&pl=18&initcwndbps=2166250&vprv=1&mime=audio%2Fwebm&ns=qToeeueJxrm79q2EEzAfkkAM&gir=yes&clen=5840382&dur=302.621&lmt=1680218132527140&mt=1680469030&fvip=4&keepalive=yes&fexp=24007246&c=WEB&txp=5532434&n=01jqWV79SJSwkQ&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&sig=AOq0QJ8wRQIgPluM5sSA7VSDiXm8AsTiCkfJ6dGaQ3HQG7sbBlW4UmoCIQDyClniI_Ag6ljVPO4pcBLVm6HB1v-w5YUGiElJydgaHw%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRQIgKMM6LEDehJJWOkAAkH21SgwBCO6YEw5Vj8llHe_aQb4CIQDtL-8vQR3gzqQsuGzrYYUGtp1DSIRcl7ZcUw4HSMs2sg%3D%3D'
# [dashsegments] Total fragments: 1
# [download] Destination: outputs//raw_audio/How stretching actually changes your muscles - Malachy McHugh.webm
# [download] 100% of 5.57MiB in 00:00
# [debug] ffmpeg command line: ffprobe -show_streams 'file:outputs//raw_audio/How stretching actually changes your muscles - Malachy McHugh.webm'
# [ffmpeg] Destination: outputs//raw_audio/How stretching actually changes your muscles - Malachy McHugh.mp3
# [debug] ffmpeg command line: ffmpeg -y -loglevel repeat+info -i 'file:outputs//raw_audio/How stretching actually changes your muscles - Malachy McHugh.webm' -vn -acodec libmp3lame -b:a 192k 'file:outputs//raw_audio/How stretching actually changes your muscles - Malachy McHugh.mp3'
# Deleting original file outputs//raw_audio/How stretching actually changes your muscles - Malachy McHugh.webm (pass -k to keep)
# Chunking audio to 600 second segments...
# Chunking 1 chunks...
# converting audio to text...
# Summarizing with model='gpt-3.5-turbo'
# Summarizing with model='gpt-3.5-turbo'
# Summaries:
# ================================================================================
# Long summary:
# ================================================================================
# - Stretching before physical activity can prevent muscle strains and tears
# - There are two types of stretching: dynamic and static
# - Muscles are viscoelastic and change under the stress of being stretched
# - Static stretching allows for improved flexibility, reducing the chance of certain muscle injuries
# - The effect is temporary and can be maintained through frequent stretching and comprehensive stretching regimen
# - Long-term improvements to your flexibility can provide a better range of motion for your joints, potentially reducing your risk of muscle injury in the short and long term
# - It's also possible to stretch too much, and stretching isn't helpful for every kind of movement. Different lifestyles require different kinds of mobility, and no single stretching regimen is flexible enough to fit every situation.
#
# ================================================================================
# Video - TL;DR
# ================================================================================
# Stretching before physical activity can reduce the risk of muscle strains and tears. There are two types of stretching and muscles are viscoelastic, so static stretching can improve flexibility temporarily but requires frequent maintenance. Long-term improvements in flexibility can reduce the risk of injury. Different lifestyles require different mobility and stretching isn't helpful for every kind of movement.

# %%
youtube_url = "https://www.youtube.com/watch?v=Yf1o0TQzry8"
outputs_dir = "outputs/"

long_summary, short_summary = summarize_youtube_video(youtube_url, outputs_dir)

print("Summaries:")
print("=" * 80)
print("Long summary:")
print("=" * 80)
print(long_summary)
print()

print("=" * 80)
print("Video - TL;DR")
print("=" * 80)
print(short_summary)
# Out:
# [debug] Encodings: locale UTF-8, fs utf-8, out UTF-8, pref UTF-8
# [debug] youtube-dl version 2021.12.17
# [debug] Git HEAD: 6fece0a96
# [debug] Python version 3.10.10 (CPython) - macOS-12.5.1-arm64-arm-64bit
# [debug] exe versions: ffmpeg 5.1.2, ffprobe 5.1.2
# [debug] Proxy map: {}
# Downloading video from https://www.youtube.com/watch?v=Yf1o0TQzry8
# [youtube] Yf1o0TQzry8: Downloading webpage
# [debug] [youtube] Decrypted nsig vxIimgC5wkrCkhKbIV => fCRhts3Tte6EQg
# [debug] [youtube] Decrypted nsig nI81qL3SsNySl9Kszc => q-A2XGXUVbaX5g
# [debug] Invoking downloader on 'https://rr4---sn-8qu-t0ay.googlevideo.com/videoplayback?expire=1680491097&ei=-e0pZOq_I5OW_9EPoI242AE&ip=96.22.200.93&id=o-ADCAnOljbdlpeI0L9yCGXzR7yP98fMdzfBvZbhM93Bsz&itag=140&source=youtube&requiressl=yes&mh=Xn&mm=31%2C29&mn=sn-8qu-t0ay%2Csn-t0a7ln7d&ms=au%2Crdu&mv=m&mvi=4&pcm2cms=yes&pl=18&initcwndbps=1718750&vprv=1&mime=audio%2Fmp4&ns=24GwWKcm3o06kxzq9mVQz7EM&gir=yes&clen=46303187&dur=2861.023&lmt=1679971561142898&mt=1680469030&fvip=5&keepalive=yes&fexp=24007246&c=WEB&txp=5532434&n=fCRhts3Tte6EQg&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&sig=AOq0QJ8wRgIhAIhiVgEpkSXXtQ_m5YrJcxk-fhNod1brmkJ5jrNAH0TBAiEAraVSj6Enuj37CvrVrEB5ZMkcfeLIH03g8Qb4QUOwKp8%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRQIgO78jUqdP5HR3IbjHBrLHqVFxGGwq-K10vj2FDeCHiQYCIQCwHHBcQDFkUFiU_CV0jVqFC8O658wRHPbo095yhk3gCA%3D%3D'
# [dashsegments] Total fragments: 5
# [download] Destination: outputs//raw_audio/Ilya Sutskever (OpenAI Chief Scientist) - Building AGI, Alignment, Spies, Microsoft, & Enlightenment.m4a
# [download]  20.0% of ~50.00MiB at 10.67MiB/s ETA 00:03407
# ERROR: giving up after 0 fragment retries
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3006, in run_cell
#     result = self._run_cell(
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3061, in _run_cell
#     result = runner(coro)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3266, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3445, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/jeremypinto/opt/miniconda3/envs/youGPTube/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/2v/40905qks05l4rnn4zz8r140w0000gp/T/ipykernel_21379/912271833.py", line 4, in <module>
#     long_summary, short_summary = summarize_youtube_video(youtube_url, outputs_dir)
#   File "/var/folders/2v/40905qks05l4rnn4zz8r140w0000gp/T/ipykernel_21379/2296989415.py", line 14, in summarize_youtube_video
#     audio_filename = youtube_to_mp3(youtube_url, output_dir=raw_audio_dir)
#   File "/var/folders/2v/40905qks05l4rnn4zz8r140w0000gp/T/ipykernel_21379/628522897.py", line 28, in youtube_to_mp3
#     ydl.download([youtube_url])
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 2083, in download
#     res = self.extract_info(
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 812, in extract_info
#     return self.__extract_info(url, ie, download, extra_info, process)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 819, in wrapper
#     return func(self, *args, **kwargs)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 851, in __extract_info
#     return self.process_ie_result(ie_result, download, extra_info)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 885, in process_ie_result
#     return self.process_video_result(ie_result, download=download)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 1696, in process_video_result
#     self.process_info(new_info)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 1988, in process_info
#     success = dl(filename, info_dict)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 1927, in dl
#     return fd.download(name, info)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/downloader/common.py", line 376, in download
#     return self.real_download(filename, info_dict)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/downloader/dash.py", line 73, in real_download
#     self.report_error('giving up after %s fragment retries' % fragment_retries)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/downloader/common.py", line 175, in report_error
#     self.ydl.report_error(*args, **kargs)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 632, in report_error
#     self.trouble(error_message, tb)
#   File "/Users/jeremypinto/youtube-dl/youtube_dl/YoutubeDL.py", line 594, in trouble
#     tb_data = traceback.format_list(traceback.extract_stack())
#
# [debug] Encodings: locale UTF-8, fs utf-8, out UTF-8, pref UTF-8
# [debug] youtube-dl version 2021.12.17
# [debug] Git HEAD: 6fece0a96
# [debug] Python version 3.10.10 (CPython) - macOS-12.5.1-arm64-arm-64bit
# [debug] exe versions: ffmpeg 5.1.2, ffprobe 5.1.2
# [debug] Proxy map: {}
# [youtube] Yf1o0TQzry8: Downloading webpage
# [debug] [youtube] Decrypted nsig YuUlB0BtIxDEM5ipIy => cLUwc-wUF_Nh2Q
# [debug] [youtube] Decrypted nsig PhOkg1TOpkjB-_iAVN => _sTqiQnNzyswdQ
# [debug] Invoking downloader on 'https://rr4---sn-8qu-t0ay.googlevideo.com/videoplayback?expire=1680491099&ei=--0pZKmfOJO58wSg96Eg&ip=96.22.200.93&id=o-AI26Cou90ub-oX3RqcHVn06gt7huNT1pcFwOO9CDdGEU&itag=140&source=youtube&requiressl=yes&mh=Xn&mm=31%2C29&mn=sn-8qu-t0ay%2Csn-t0a7ln7d&ms=au%2Crdu&mv=m&mvi=4&pcm2cms=yes&pl=18&initcwndbps=1718750&vprv=1&mime=audio%2Fmp4&ns=-cGbzkZC_9aniZDlmIRWROcM&gir=yes&clen=46303187&dur=2861.023&lmt=1679971561142898&mt=1680469030&fvip=5&keepalive=yes&fexp=24007246&c=WEB&txp=5532434&n=cLUwc-wUF_Nh2Q&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cvprv%2Cmime%2Cns%2Cgir%2Cclen%2Cdur%2Clmt&sig=AOq0QJ8wRQIgHU_71iRSCIpeT-D7nKW55hqv_zTQ7OOpV9qr_sGEl-gCIQDjJiArbK9wXSBLoCOmD_V8tBjZtpOia8paZ9f4xwffpg%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpcm2cms%2Cpl%2Cinitcwndbps&lsig=AG3C_xAwRgIhAPJ-h4Fu4dZ6hchVMYK06HcAr3WKzw73XQQ0Y-sMOCA1AiEArH2hX-XUsRQ4tWSvd6l_xtbBnLxf41qUnTRXdnmdf60%3D'
# [dashsegments] Total fragments: 5
# [download] Destination: outputs//raw_audio/Ilya Sutskever (OpenAI Chief Scientist) - Building AGI, Alignment, Spies, Microsoft, & Enlightenment.m4a
# [download]  40.0% of ~50.00MiB at 11.86MiB/s ETA 00:029[download] Skipping fragment 2...
# [download]  60.0% of ~50.00MiB at 11.56MiB/s ETA 00:016[download] Skipping fragment 3...
# [download]  80.0% of ~50.00MiB at 12.67MiB/s ETA 00:000[download] Skipping fragment 4...
# [download] 100.0% of ~44.16MiB at 10.25MiB/s ETA 00:0004[download] Skipping fragment 5...
# [download] 100% of 44.16MiB in 00:02
# [ffmpeg] Correcting container in "outputs//raw_audio/Ilya Sutskever (OpenAI Chief Scientist) - Building AGI, Alignment, Spies, Microsoft, & Enlightenment.m4a"
# [debug] ffmpeg command line: ffmpeg -y -loglevel repeat+info -i 'file:outputs//raw_audio/Ilya Sutskever (OpenAI Chief Scientist) - Building AGI, Alignment, Spies, Microsoft, & Enlightenment.m4a' -c copy -f mp4 'file:outputs//raw_audio/Ilya Sutskever (OpenAI Chief Scientist) - Building AGI, Alignment, Spies, Microsoft, & Enlightenment.temp.m4a'
# [debug] ffmpeg command line: ffprobe -show_streams 'file:outputs//raw_audio/Ilya Sutskever (OpenAI Chief Scientist) - Building AGI, Alignment, Spies, Microsoft, & Enlightenment.m4a'
# [ffmpeg] Destination: outputs//raw_audio/Ilya Sutskever (OpenAI Chief Scientist) - Building AGI, Alignment, Spies, Microsoft, & Enlightenment.mp3
# [debug] ffmpeg command line: ffmpeg -y -loglevel repeat+info -i 'file:outputs//raw_audio/Ilya Sutskever (OpenAI Chief Scientist) - Building AGI, Alignment, Spies, Microsoft, & Enlightenment.m4a' -vn -acodec libmp3lame -b:a 192k 'file:outputs//raw_audio/Ilya Sutskever (OpenAI Chief Scientist) - Building AGI, Alignment, Spies, Microsoft, & Enlightenment.mp3'
# Deleting original file outputs//raw_audio/Ilya Sutskever (OpenAI Chief Scientist) - Building AGI, Alignment, Spies, Microsoft, & Enlightenment.m4a (pass -k to keep)
# Chunking audio to 600 second segments...
# Chunking 5 chunks...
# converting audio to text...
# Summarizing with model='gpt-3.5-turbo'
# Summarizing with model='gpt-3.5-turbo'
# Summaries:
# ================================================================================
# Long summary:
# ================================================================================
# - AI alignment with smarter models and avoiding misrepresentation is a challenge
# - Not worried about leaks, AGI can help interact with the world more correctly
# - Microsoft has been a good partner for OpenAI
# - Next token prediction can surpass human performance with a smart enough neural net
# - Interview with Ilya Sutskover, co-founder and chief scientist of OpenAI
# - Possibility of illegal uses of GPT by foreign governments or scammers
# - Large-scale tracking of illegal uses of AI is possible
# - AI's economic value is increasing year after year before AGI
# - Reliability is key for AI to have real-world impact and produce economic value
# - The next paradigm after generative models will likely integrate past ideas
# - Next token prediction can deduce hypothetical qualities of a person to surpass human performance
# - Most data for reinforcement learning already comes from AI, with humans training the reward function
# - Hope to remove humans from the loop and have AI improve itself, similar to AlphaGo.
# - The future of AI is a collaboration between humans and machines.
# - Current models have issues with multi-step reasoning, but can improve through better models and training.
# - At some point, data may run out, but there are still valuable sources available.
# - Going multimodal is a fruitful direction for improving AI.
# - Achieving mathematical alignment is unlikely, but multiple approaches from various aspects can reduce the probability of misalignment.
# - Understanding of AI models is still quite rudimentary and there's room for improvement.
# - The bottleneck in AI research is good ideas and insights, which neural nets can help with.
# - A billion-dollar prize for alignment research could be awarded retroactively for making a lot of progress.
# - End-to-end training and connecting things together are both promising in improving AI.
# - OpenAI is projecting billion-dollar revenues in 2024, but it's hard to estimate the windfall of a new general purpose technology.
# - The speaker reflects on the growth of the company's AI products since GPT-3 and how the response to DALI has grown.
# - They believe that data is important for making predictions about the future of AI.
# - They discuss the potential implications of a post-AGI future and see potential for AGI to help people become more enlightened.
# - The speaker thinks about how the world may change after AGI is built and hopes that humans will still have agency and be able to progress on their own.
# - They assert that hardware is similar and that the only thing that matters about hardware is its cost.
# - The speaker emphasizes that a lot of their work is spent on understanding current results and figuring out what experiments to run next.
# - They reflect on ImageNet and describe it as a new understanding of very old things.
# - The speaker is grateful for the partnership with Microsoft and praises Azure for its suitability for ML.
# - They acknowledge that a disaster in Taiwan might be a setback for AI, but that it wouldn't be the end of the industry.
# - There is potential for cost-prohibitive inference as models get bigger.
# - Inference of better models may become more expensive, but it depends on how useful it is.
# - There will be price discrimination and different models of different sizes and capabilities will be available.
# - Progress in improving and making models more reliable and trustworthy will prevent models from becoming commodities.
# - Different companies may specialize in different areas to respond to commoditization.
# - Security is a concern as the weights of the models can be leaked.
# - Emergent properties of models at this scale may include reliability and controllability.
# - Linking next word prediction accuracy to reasoning capability is complicated and other approaches like reasoning tokens can be helpful.
# - The arrival of data, GPUs, and transformers at the same time is intertwined and progress is inevitable.
# - Alignment of models smarter than us and capable of misrepresenting their intentions will be difficult.
# - Alignment research is an area where academic researchers can contribute meaningfully.
# - Academic research can come up with insights about actual capabilities beyond what companies do.
# - There is no clean distinction between the world of bits and the world of atoms.
# - Breakthroughs can come from a big conceptual idea or by implementing something from the books.
# - Inspiration from humans and the brain should be done with care, focusing on essential behaviors and emergent phenomena.
# - Perseverance is a necessary but not sufficient condition for success.
#
# ================================================================================
# Video - TL;DR
# ================================================================================
# The co-founder and chief scientist of OpenAI discusses a variety of topics including AI alignment, economic value, reliability, and the future of AI as a collaboration between humans and machines. They acknowledge the difficulty of achieving alignment with models smarter than us and the potential for illegal or malicious uses of AI. They also emphasize the importance of data for making predictions about the future of AI and the potential for AGI to help people become more enlightened.
